# %% [markdown]
# <a href="https://colab.research.google.com/github/irahimov646/Flight_trajectory_simulator/blob/main/flight_Trajectory_Simulator_ipynt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

html_content = """
<!DOCTYPE html>
<html lang="ru">
<head>
    <meta charset="UTF-8">
    <title>Flight Trajectory Simulator Presentation</title>
    <style>
        body { font-family: 'Segoe UI', Arial, sans-serif; background-color: #f4f6f9; margin: 0; padding: 40px; color: #202124; }
        .slide { background: white; max-width: 900px; height: 500px; margin: 0 auto 40px auto; padding: 40px; box-shadow: 0 4px 10px rgba(0,0,0,0.08); border-radius: 8px; position: relative; box-sizing: border-box; display: flex; flex-direction: column; justify-content: flex-start; }
        .title-slide { justify-content: center; background: linear-gradient(135deg, #0b1d3a 0%, #1a2f4c 100%); color: white; }
        h1 { font-size: 38px; color: #0b1d3a; margin-top: 0; }
        .title-slide h1 { color: #ffffff; font-size: 48px; margin-bottom: 10px; }
        .subtitle { font-size: 20px; color: #1a73e8; }
        .title-slide .subtitle { color: #8ab4f8; }
        h2 { font-size: 24px; color: #0b1d3a; margin-bottom: 20px; border-bottom: 2px solid #1a73e8; padding-bottom: 8px; }
        ul { font-size: 16px; line-height: 1.6; }
        li { margin-bottom: 12px; }
        .content-layout { display: flex; gap: 30px; height: 100%; }
        .text-side { flex: 1; }
        .visual-side { flex: 1; display: flex; align-items: center; justify-content: center; background: #fafafa; border: 1px solid #e0e0e0; border-radius: 6px; position: relative; }
        table { width: 100%; border-collapse: collapse; margin-top: 15px; font-size: 14px; }
        th, td { padding: 10px; text-align: left; border-bottom: 1px solid #e0e0e0; }
        th { background-color: #0b1d3a; color: white; }
        .badge { font-size: 12px; padding: 2px 6px; border-radius: 4px; font-weight: bold; background: #e8f0fe; color: #1a73e8; }
    </style>
</head>
<body>

    <!-- СЛАЙД 1: ТИТУЛЬНЫЙ -->
    <div class="slide title-slide">
        <h1>Flight Trajectory Simulator</h1>
        <div class="subtitle">Математическое моделирование динамики полета в 3D пространстве</div>
    </div>

    <!-- СЛАЙД 2: ФИЗИКА МОДЕЛИ -->
    <div class="slide">
        <h2>1. Физические основы моделирования</h2>
        <p>Симулятор рассчитывает пространственное движение воздушного судна (ВС) как материальной точки или твердого тела, вычисляя баланс четырех фундаментальных аэродинамических сил в каждый момент времени:</p>
        <ul>
            <li><strong>Тяга (Thrust)</strong> — сила, создаваемая пропульсивной системой (двигателями) ВС.</li>
            <li><strong>Лобовое сопротивление (Drag)</strong> — сила торможения, направленная противоположно вектору скорости.</li>
            <li><strong>Подъемная сила (Lift)</strong> — перпендикулярна вектору скорости, удерживает аппарат в воздухе.</li>
            <li><strong>Вес (Weight)</strong> — гравитационная сила, зависящая от текущей массы самолета и выработки топлива.</li>
        </ul>
    </div>

    <!-- СЛАЙД 3: СРАВНИТЕЛЬНАЯ ТАБЛИЦА МЕТОДОВ -->
    <div class="slide">
        <h2>2. Выбор математического метода решения</h2>
        <p>Для интеграции дифференциальных уравнений движения во времени применяются численные методы:</p>
        <table>
            <thead>
                <tr>
                    <th>Метод интеграции</th>
                    <th>Точность расчета</th>
                    <th>Вычислительный шаг</th>
                    <th>Сфера применения</th>
                </tr>
            </thead>
            <tbody>
                <tr>
                    <td><strong>Метод Эйлера</strong></td>
                    <td>Низкая (1-й порядок)</td>
                    <td>Требует малый шаг, копит ошибку</td>
                    <td>Простые тесты, real-time игры</td>
                </tr>
                <tr>
                    <td><strong>Рунге-Кутты (RK4)</strong></td>
                    <td><span class="badge">Высокая (4-й порядок)</span></td>
                    <td>Оптимальный шаг, стабилен</td>
                    <td>Инженерные симуляторы, автопилоты</td>
                </tr>
                <tr>
                    <td><strong>Метод Верле</strong></td>
                    <td>Средняя (2-й порядок)</td>
                    <td>Отлично сохраняет энергию</td>
                    <td>Физика частиц, гибкие элементы</td>
                </tr>
            </tbody>
        </table>
    </div>

    <!-- СЛАЙД 4: 3D ВИЗУАЛИЗАЦИЯ -->
    <div class="slide">
        <h2>3. 3D Моделирование траектории</h2>
        <div class="content-layout">
            <div class="text-side">
                <p>В отличие от плоских двухмерных моделей, продвинутый трехмерный симулятор комплексно обрабатывает:</p>
                <ul>
                    <li>Динамический крен (Roll), тангаж (Pitch) и рыскание (Yaw).</li>
                    <li>Изменение плотности воздуха и температуры среды в зависимости от высоты.</li>
                    <li>Векторные сдвиги ветра на различных эшелонах.</li>
                </ul>
                <p><em>На графике справа:</em> Пример симуляции сложного маневра — разворот ВС с одновременным набором высоты (пространственная спираль).</p>
            </div>
            <div class="visual-side">
                <!-- Встроенный SVG-эскиз 3D-графика -->
                <svg width="100%" height="100%" viewBox="0 0 300 250" style="background:#fcfcfc;">
                    <path d="M 50 200 L 250 200 M 50 200 L 50 50 M 50 200 L 120 150" stroke="#ccc" stroke-width="1.5" />
                    <path d="M 60 190 Q 100 180 130 140 T 200 90 T 240 60" fill="none" stroke="#1a73e8" stroke-width="3" />
                    <circle cx="60" cy="190" r="5" fill="green" />
                    <circle cx="240" cy="60" r="5" fill="red" />
                    <text x="70" y="195" font-size="10" fill="green">Взлет</text>
                    <text x="180" y="55" font-size="10" fill="red">Эшелон (3D)</text>
                    <text x="240" y="215" font-size="9" fill="#666">Ось X</text>
                    <text x="20" y="50" font-size="9" fill="#666">Высота Z</text>
                </svg>
            </div>
        </div>
    </div>

    <!-- СЛАЙД 5: ЗАКЛЮЧЕНИЕ -->
    <div class="slide">
        <h2>Заключение и сферы применения</h2>
        <p>Flight Trajectory Simulator является базовым ядром для решения критически важных авиационных задач:</p>
        <ul>
            <li><strong>Оптимизация маршрутов:</strong> Снижение коммерческих расходов авиакомпаний за счет расчета оптимального профиля полета под разный ветер.</li>
            <li><strong>Проектирование систем управления:</strong> Наземное тестирование алгоритмов автопилота перед установкой на реальные БПЛА и самолеты.</li>
            <li><strong>Авиатренажеры:</strong> Математическая основа комплексных тренажеров для подготовки пилотов гражданской и военной авиации.</li>
        </ul>
    </div>

</body>
</html>
"""

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="ru">
# <head>
#     <meta charset="UTF-8">
#     <title>Flight Trajectory Simulator Presentation</title>
#     <style>
#         body { font-family: 'Segoe UI', Arial, sans-serif; background-color: #f4f6f9; margin: 0; padding: 40px; color: #202124; }
#         .slide { background: white; max-width: 900px; height: 500px; margin: 0 auto 40px auto; padding: 40px; box-shadow: 0 4px 10px rgba(0,0,0,0.08); border-radius: 8px; position: relative; box-sizing: border-box; display: flex; flex-direction: column; justify-content: flex-start; }
#         .title-slide { justify-content: center; background: linear-gradient(135deg, #0b1d3a 0%, #1a2f4c 100%); color: white; }
#         h1 { font-size: 38px; color: #0b1d3a; margin-top: 0; }
#         .title-slide h1 { color: #ffffff; font-size: 48px; margin-bottom: 10px; }
#         .subtitle { font-size: 20px; color: #1a73e8; }
#         .title-slide .subtitle { color: #8ab4f8; }
# ...
